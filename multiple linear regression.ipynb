# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("X:\\Neil\\Code\\coding IEEE\\CSV\\housing.csv")

# %%
data = data.replace({'yes': 1, 'no': 0})
data = data.replace({'furnished' : 1,'semi-furnished' : 0.5, 'unfurnished' : 0})
data
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
data=data[data.notnull().all(1)]
data
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
x = np.array(data.iloc[0: ,1:])
y = np.array(data.iloc[0: ,0:1])
x.shape
# Out:
# (545, 12)

# %%
def loss_function(w,b,x,y):
    total_error = 0
    ##for i in range(len(x)):
        ##xd = x[i]
        ##yd = y[i]
    y_hat=[]
    for i in range(len(x)):
        y_hat.append(np.dot(w,x[i]) + b)
    y_hat=np.array(y_hat)
    total_error = np.sum((y_hat-y)**2)
        
        ##total_error += (yd - (np.dot(w,xd) + b)) ** 2
    total_cost = total_error/(len(x))
    return total_cost

# %%
def gd(x,y,l,w_now,b_now):
    w_gradient = np.zeros(12)
    b_gradient = 0
    
    n = len(x)
    
    for i in range(len(x)): 
        xd = x[i]
        yd = y[i]
        
        w_gradient += (1/n)*xd*(yd - (np.dot(w_now,xd) + b_now))
        b_gradient += (1/n)*(yd-(np.dot(w_now,xd) + b_now))
    
    w = w_now - l*w_gradient
    b = b_now - l*b_gradient
    return w,b

# %%
w = np.zeros(12)
b = 0
epochs = 1000
l = 0.0000000001


for i in range(epochs):
    w,b = gd(x,y,l,w,b,)
    cost = loss_function(w,b,x,y)
    if i % 50 == 0:
        print(f"epochs: {i}")
        print(cost)
        print(w)

print(w,b)
# Out:
# epochs: 0
# 26356878714527.96
# [-2.67229201e+00 -1.46390263e-03 -6.61666767e-04 -9.28774360e-04
#  -4.28651705e-04 -1.03102936e-04 -1.83732018e-04 -2.55044037e-05
#  -1.89775035e-04 -3.92442914e-04 -1.38076670e-04 -2.43376411e-04]
# epochs: 50
# 34775948881029.11
# [-1.47490818e+02 -8.02252560e-02 -3.61974612e-02 -5.07604148e-02
#  -2.35262789e-02 -5.62887485e-03 -1.00355245e-02 -1.38398627e-03
#  -1.03420983e-02 -2.15325623e-02 -7.55331689e-03 -1.33224217e-02]
# epochs: 100
# 46275435445819.42
# [-3.16741836e+02 -1.71124914e-01 -7.70813463e-02 -1.07991028e-01
#  -5.02548764e-02 -1.19628719e-02 -2.13379056e-02 -2.92403755e-03
#  -2.19414773e-02 -4.59829388e-02 -1.60837858e-02 -2.83864014e-02]
# epochs: 150
# 61982418365431.734
# [-5.14547376e+02 -2.76210742e-01 -1.24215604e-01 -1.73868903e-01
#  -8.12270292e-02 -1.92414506e-02 -3.43356055e-02 -4.67629102e-03
#  -3.52320462e-02 -7.43020497e-02 -2.59176350e-02 -4.57701958e-02]
# epochs: 200
# 83436359905856.77
# ...
